# %% [markdown]
# <a href="https://colab.research.google.com/github/denzelaldriche-cpu/CS1-python-7-Emerald-Ermitanio/blob/fa3program/fa3programing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **fa3prog1**

# %%
name = input()
# Out:
# d

# %%
age = input()
# Out:
# d

# %%
course = input()
# Out:
# d

# %%
print(f"Name: {name}\nAge: {age}\nCourse: {course}")
# Out:
# Name: s
# Age: d
# Course: d

# %% [markdown]
# **fa3prog2**

# %%
score = input()
# Out:
# 12

# %%
if int(score) >= 75:
    print("Passed")
else:
    print("Failed")
# Out:
# Failed

# %% [markdown]
# **fa3prog3**

# %%
name = input()
# Out:
# h

# %%
score = input()
# Out:
# 0

# %%
if int(score) <= 100 and int(score) >= 90:
  print("A")
elif int(score) <= 89 and int(score) >= 80:
  print("B")
elif int(score) <= 79 and int(score) >= 70:
  print("C")
else:
  print("F")
# Out:
# F
