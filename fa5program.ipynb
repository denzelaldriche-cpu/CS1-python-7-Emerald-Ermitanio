# %% [markdown]
# <a href="https://colab.research.google.com/github/denzelaldriche-cpu/CS1-python-7-Emerald-Ermitanio/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_total(price, quantity):
    total = price * quantity
    return total

price = float(input("How much is the product? "))
quantity = int(input("How many products will you buy? "))

final_total = calculate_total(price, quantity)

print("Your total is:", final_total)
